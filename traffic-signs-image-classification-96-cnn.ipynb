# %% [markdown]
# # 1. Download and Imports

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import os

# Image related
import cv2
from PIL import Image

#Performance Plot
from sklearn import metrics 
from sklearn.metrics import f1_score, accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# For the model and it's training
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# Time
import time
import datetime

# %% [markdown]
# # 2. Functions

# %%
# date_time function

def date_time(x):
    if x==1:
        return 'Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
    if x==2:    
        return 'Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now())
    if x==3:  
        return 'Date now: %s' % datetime.datetime.now()
    if x==4:  
        return 'Date today: %s' % datetime.date.today()

# %%
# Performance Plot

def plot_performance(history=None, figure_directory=None, ylim_pad=[0, 0]):
    xlabel = 'Epoch'
    legends = ['Training', 'Validation']

    plt.figure(figsize=(20, 5))

    y1 = history.history['accuracy']
    y2 = history.history['val_accuracy']

    min_y = min(min(y1), min(y2))-ylim_pad[0]
    max_y = max(max(y1), max(y2))+ylim_pad[0]


    plt.subplot(121)

    plt.plot(y1)
    plt.plot(y2)

    plt.title('Model Accuracy\n'+date_time(1), fontsize=17)
    plt.xlabel(xlabel, fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.ylim(min_y, max_y)
    plt.legend(legends, loc='upper left')
    plt.grid()

    y1 = history.history['loss']
    y2 = history.history['val_loss']

    min_y = min(min(y1), min(y2))-ylim_pad[1]
    max_y = max(max(y1), max(y2))+ylim_pad[1]


    plt.subplot(122)

    plt.plot(y1)
    plt.plot(y2)

    plt.title('Model Loss\n'+date_time(1), fontsize=17)
    plt.xlabel(xlabel, fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.ylim(min_y, max_y)
    plt.legend(legends, loc='upper left')
    plt.grid()
    if figure_directory:
        plt.savefig(figure_directory+"/history")

    plt.show()

# %% [markdown]
# # 3. Loading Dataset (Traffic Signs Images)

# %%
# Setting variables for later use
data = []
labels = []
classes = 43
cur_path = os.getcwd()

# Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join('/Users/raguls_mac/Downloads/archive/','Train',str(i))
    images = os.listdir(path)

    for a in images:
        try:
            image = Image.open(path + '/'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

# Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)

# %% [markdown]
# # 4. Data Splitting and conversion

# %%
# Checking data shape
print(data.shape, labels.shape)

# Splitting training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Displaying the shape after the split
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# Converting the labels into one hot encoding
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)
# Out:
# (39209, 30, 30, 3) (39209,)
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %% [markdown]
# # 5. Creating and Compiling the Model

# %%
# Building the model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=64, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.15))
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.20))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(43, activation='softmax'))

# Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#M odel display
model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 22, 22, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 11, 11, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 11, 11, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 9, 9, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 43)             │        22,059 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,624,939 (6.20 MB)
#  Trainable params: 1,624,939 (6.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 6. Training the Model

# %%
# Training the Model
with tf.device('/GPU:0'):
    epochs = 40
    history1 = model.fit(X_train, y_train, batch_size=64, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 49s 98ms/step - accuracy: 0.5333 - loss: 2.7641 - val_accuracy: 0.9702 - val_loss: 0.1309
# Epoch 2/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 52s 106ms/step - accuracy: 0.9475 - loss: 0.1970 - val_accuracy: 0.9763 - val_loss: 0.1010
# Epoch 3/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 53s 108ms/step - accuracy: 0.9648 - loss: 0.1319 - val_accuracy: 0.9815 - val_loss: 0.0803
# Epoch 4/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9737 - loss: 0.0922 - val_accuracy: 0.9885 - val_loss: 0.0477
# Epoch 5/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 63s 129ms/step - accuracy: 0.9756 - loss: 0.0886 - val_accuracy: 0.9866 - val_loss: 0.0569
# Epoch 6/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 126ms/step - accuracy: 0.9698 - loss: 0.1188 - val_accuracy: 0.9867 - val_loss: 0.0537
# Epoch 7/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 61s 124ms/step - accuracy: 0.9766 - loss: 0.0882 - val_accuracy: 0.9904 - val_loss: 0.0443
# Epoch 8/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 65s 132ms/step - accuracy: 0.9843 - loss: 0.0596 - val_accuracy: 0.9920 - val_loss: 0.0331
# Epoch 9/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 66s 134ms/step - accuracy: 0.9797 - loss: 0.0848 - val_accuracy: 0.9939 - val_loss: 0.0352
# Epoch 10/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 68s 138ms/step - accuracy: 0.9790 - loss: 0.0999 - val_accuracy: 0.9944 - val_loss: 0.0283
# Epoch 11/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 67s 137ms/step - accuracy: 0.9864 - loss: 0.0570 - val_accuracy: 0.9820 - val_loss: 0.1036
# Epoch 12/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 70s 143ms/step - accuracy: 0.9775 - loss: 0.0978 - val_accuracy: 0.9899 - val_loss: 0.0486
# Epoch 13/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 75s 152ms/step - accuracy: 0.9802 - loss: 0.0892 - val_accuracy: 0.9939 - val_loss: 0.0329
# Epoch 14/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 70s 143ms/step - accuracy: 0.9855 - loss: 0.0689 - val_accuracy: 0.9944 - val_loss: 0.0333
# Epoch 15/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 68s 139ms/step - accuracy: 0.9858 - loss: 0.0587 - val_accuracy: 0.9939 - val_loss: 0.0286
# Epoch 16/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 68s 139ms/step - accuracy: 0.9857 - loss: 0.0696 - val_accuracy: 0.9838 - val_loss: 0.0933
# Epoch 17/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 71s 144ms/step - accuracy: 0.9805 - loss: 0.0919 - val_accuracy: 0.9917 - val_loss: 0.0473
# Epoch 18/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 68s 138ms/step - accuracy: 0.9849 - loss: 0.0744 - val_accuracy: 0.9930 - val_loss: 0.0382
# Epoch 19/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 63s 128ms/step - accuracy: 0.9851 - loss: 0.0638 - val_accuracy: 0.9932 - val_loss: 0.0472
# Epoch 20/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 126ms/step - accuracy: 0.9875 - loss: 0.0621 - val_accuracy: 0.9938 - val_loss: 0.0342
# Epoch 21/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 61s 125ms/step - accuracy: 0.9895 - loss: 0.0532 - val_accuracy: 0.9926 - val_loss: 0.0443
# Epoch 22/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 61s 124ms/step - accuracy: 0.9845 - loss: 0.0886 - val_accuracy: 0.9930 - val_loss: 0.0386
# Epoch 23/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 125ms/step - accuracy: 0.9844 - loss: 0.0793 - val_accuracy: 0.9901 - val_loss: 0.0436
# Epoch 24/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 127ms/step - accuracy: 0.9873 - loss: 0.0595 - val_accuracy: 0.9935 - val_loss: 0.0368
# Epoch 25/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 65s 132ms/step - accuracy: 0.9870 - loss: 0.0685 - val_accuracy: 0.9880 - val_loss: 0.0900
# Epoch 26/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 65s 133ms/step - accuracy: 0.9794 - loss: 0.1401 - val_accuracy: 0.9892 - val_loss: 0.1055
# Epoch 27/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 65s 133ms/step - accuracy: 0.9854 - loss: 0.0929 - val_accuracy: 0.9936 - val_loss: 0.0459
# Epoch 28/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 63s 129ms/step - accuracy: 0.9906 - loss: 0.0521 - val_accuracy: 0.9940 - val_loss: 0.0595
# Epoch 29/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 63s 128ms/step - accuracy: 0.9858 - loss: 0.0828 - val_accuracy: 0.9772 - val_loss: 0.1096
# Epoch 30/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 127ms/step - accuracy: 0.9880 - loss: 0.0666 - val_accuracy: 0.9945 - val_loss: 0.0327
# Epoch 31/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 126ms/step - accuracy: 0.9854 - loss: 0.0819 - val_accuracy: 0.9876 - val_loss: 0.0698
# Epoch 32/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 67s 137ms/step - accuracy: 0.9854 - loss: 0.0966 - val_accuracy: 0.9948 - val_loss: 0.0328
# Epoch 33/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 67s 137ms/step - accuracy: 0.9921 - loss: 0.0385 - val_accuracy: 0.9892 - val_loss: 0.1403
# Epoch 34/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 67s 135ms/step - accuracy: 0.9860 - loss: 0.1050 - val_accuracy: 0.9950 - val_loss: 0.0588
# Epoch 35/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 67s 137ms/step - accuracy: 0.9902 - loss: 0.0633 - val_accuracy: 0.9943 - val_loss: 0.0532
# Epoch 36/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 73s 149ms/step - accuracy: 0.9917 - loss: 0.0598 - val_accuracy: 0.9932 - val_loss: 0.0465
# Epoch 37/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 78s 158ms/step - accuracy: 0.9913 - loss: 0.0690 - val_accuracy: 0.9927 - val_loss: 0.0568
# Epoch 38/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 63s 127ms/step - accuracy: 0.9879 - loss: 0.0837 - val_accuracy: 0.9935 - val_loss: 0.0545
# Epoch 39/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 60s 121ms/step - accuracy: 0.9875 - loss: 0.0904 - val_accuracy: 0.9945 - val_loss: 0.0513
# Epoch 40/40
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 62s 126ms/step - accuracy: 0.9884 - loss: 0.0822 - val_accuracy: 0.9913 - val_loss: 0.0643

# %% [markdown]
# # 7. Visualizing the performance of the Model during Training Phase

# %%
plot_performance(history=history1)

# %% [markdown]
# # 8. Loading Test Dataset and Evaluating the Model

# %%
# testing accuracy on test dataset
from sklearn.metrics import accuracy_score

# Importing the test dataset
y_test = pd.read_csv('/Users/raguls_mac/Downloads/archive/Test.csv')

labels = y_test["ClassId"].values
imgs = y_test["Path"].values

data=[]

# Retreiving the images
with tf.device('/GPU:0'):
    for img in imgs:
        image = Image.open('/Users/raguls_mac/Downloads/archive/'+img)
        image = image.resize([30, 30])
        data.append(np.array(image))

X_test=np.array(data)

# %%
with tf.device('/GPU:0'):
    pred = np.argmax(model.predict(X_test), axis=-1)

#Accuracy with the test data
from sklearn.metrics import accuracy_score
print(accuracy_score(labels, pred))
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
# 0.9595407759303246

# %% [markdown]
# # 9. Saving the Model

# %%
# Saving the Model 
model.save('traffic_classifier.keras')
